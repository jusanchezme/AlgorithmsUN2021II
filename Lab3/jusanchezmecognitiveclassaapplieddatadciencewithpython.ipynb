# %% [markdown]
# <a href="https://colab.research.google.com/github/jusanchezme/AlgorithmsUN2022I/blob/Lab3/Lab3/jusanchezmecognitiveclassaapplieddatadciencewithpython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Certificates
# 1.   [Python 101 for Data Science](https://courses.cognitiveclass.ai/certificates/936b48d819384d569e6634eb2a971b3e)
# 2.   [Data Analysis with Python](https://courses.cognitiveclass.ai/certificates/69e2ad1caaee41448c4e46cbb4cb15b2)
# 3.   [Data Visualization with Python](https://courses.cognitiveclass.ai/certificates/64ebd23e697e466e848cb5a80ae097b5)

# %% [markdown]
# **Linkedin Licences & certifications**
# ![jusanchezmecognitiveclassaapplieddatadciencewithpython.jpg](data:image/jpeg;base64,...)
